# %%
import cv2

# %%
def tracker_secelcion():
    print("Hello! What Tracking API would you like to use?")
    print("Enter 0 for BOOSTING.")
    print("Enter 1 for MIL.")
    print("Enter 2 for KCF.")
    print("Enter 3 for TLD.")
    print("Enter 4 for MedianFlow.")
    
    choice = input("Please select assigned number of your tracker: ")
    
    if choice == '0':
        tracker = cv2.TrackerBoosting_create()
    if choice == '1':
        tracker = cv2.TrackerMIL_create()
    if choice == '2':
        tracker = cv2.TrackerKCF_create()
    if choice == '3':
        tracker = cv2.TrackerTLD_create()
    if choice == '4':
        tracker = cv2.TrackerMedianFlow_create()
        
    return tracker

# %%
tracker = tracker_secelcion()
tracker_name = str(tracker).split()[0][1:]

cap = cv2.VideoCapture(0)
ret, frame = cap.read()

# selectROI allows to draw the ROI on the very first frame
roi= cv2.selectROI(frame, False)

ret = tracker.init(frame, roi)

while True:
    
    ret, frame = cap.read()
    
    # Update the tracker for current frame
    success, roi = tracker.update(frame)
    
    #ROI variable is a tuple of 4 floats
    (x,y,w,h) = tuple(map(int,roi))
    
    # Draw rectangle while Tracker moves
    if success:
        cv2.rectangle(frame, (x,y), (x+w,y+h), (0,255,255), 2)
    else:
        cv2.putText(frame, "Failed to Detect Tracker!!!", (100,100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)
    
    cv2.putText(frame, tracker_name, (20,300), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)
    
    cv2.imshow(tracker_name, frame)
    
    k = cv2.waitKey(10) & 0xFF
    if k == 27:
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# Hello! What Tracking API would you like to use?
# Enter 0 for BOOSTING.
# Enter 1 for MIL.
# Enter 2 for KCF.
# Enter 3 for TLD.
# Enter 4 for MedianFlow.
# Please select assigned number of your tracker:  1
