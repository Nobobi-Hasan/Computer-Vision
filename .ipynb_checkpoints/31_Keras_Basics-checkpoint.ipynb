# %%
import numpy as np
from numpy import genfromtxt

# %%
data = genfromtxt('DATA/bank_note_data.txt', delimiter=',')

# %%
data
# Out:
# array([[  3.6216 ,   8.6661 ,  -2.8073 ,  -0.44699,   0.     ],
#        [  4.5459 ,   8.1674 ,  -2.4586 ,  -1.4621 ,   0.     ],
#        [  3.866  ,  -2.6383 ,   1.9242 ,   0.10645,   0.     ],
#        ...,
#        [ -3.7503 , -13.4586 ,  17.5932 ,  -2.7771 ,   1.     ],
#        [ -3.5637 ,  -8.3827 ,  12.393  ,  -1.2823 ,   1.     ],
#        [ -2.5419 ,  -0.65804,   2.6842 ,   1.1952 ,   1.     ]])

# %%
labels = data[:,-1]

# %%
labels
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
features = data[:,:-1]

# %%
features
# Out:
# array([[  3.6216 ,   8.6661 ,  -2.8073 ,  -0.44699],
#        [  4.5459 ,   8.1674 ,  -2.4586 ,  -1.4621 ],
#        [  3.866  ,  -2.6383 ,   1.9242 ,   0.10645],
#        ...,
#        [ -3.7503 , -13.4586 ,  17.5932 ,  -2.7771 ],
#        [ -3.5637 ,  -8.3827 ,  12.393  ,  -1.2823 ],
#        [ -2.5419 ,  -0.65804,   2.6842 ,   1.1952 ]])

# %%
X = features
y = labels

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler_object = MinMaxScaler()
scaler_object.fit(X_train)

scaled_X_train = scaler_object.transform(X_train)
scaled_X_test = scaler_object.transform(X_test)

# %%
scaled_X_test.max()
# Out:
# 1.02679563427227

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()

model.add(Dense(4, input_dim=4, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(scaled_X_train, y_train, epochs=50, verbose=2)
# Out:
# Epoch 1/50
#  - 0s - loss: 0.6880 - acc: 0.5552
# Epoch 2/50
#  - 0s - loss: 0.6728 - acc: 0.5875
# Epoch 3/50
#  - 0s - loss: 0.6581 - acc: 0.6417
# Epoch 4/50
#  - 0s - loss: 0.6463 - acc: 0.6771
# Epoch 5/50
#  - 0s - loss: 0.6324 - acc: 0.7729
# Epoch 6/50
#  - 0s - loss: 0.6182 - acc: 0.7958
# Epoch 7/50
#  - 0s - loss: 0.6023 - acc: 0.7927
# Epoch 8/50
#  - 0s - loss: 0.5852 - acc: 0.8417
# Epoch 9/50
#  - 0s - loss: 0.5653 - acc: 0.8344
# Epoch 10/50
#  - 0s - loss: 0.5437 - acc: 0.8729
# Epoch 11/50
#  - 0s - loss: 0.5204 - acc: 0.8729
# Epoch 12/50
#  - 0s - loss: 0.4957 - acc: 0.8833
# Epoch 13/50
#  - 0s - loss: 0.4711 - acc: 0.8823
# Epoch 14/50
#  - 0s - loss: 0.4473 - acc: 0.8885
# Epoch 15/50
#  - 0s - loss: 0.4223 - acc: 0.8927
# Epoch 16/50
#  - 0s - loss: 0.3995 - acc: 0.8938
# Epoch 17/50
#  - 0s - loss: 0.3768 - acc: 0.8979
# Epoch 18/50
#  - 0s - loss: 0.3550 - acc: 0.9000
# Epoch 19/50
#  - 0s - loss: 0.3347 - acc: 0.9240
# Epoch 20/50
#  - 0s - loss: 0.3159 - acc: 0.9271
# Epoch 21/50
#  - 0s - loss: 0.2974 - acc: 0.9354
# Epoch 22/50
#  - 0s - loss: 0.2807 - acc: 0.9490
# Epoch 23/50
#  - 0s - loss: 0.2650 - acc: 0.9490
# Epoch 24/50
#  - 0s - loss: 0.2502 - acc: 0.9563
# Epoch 25/50
#  - 0s - loss: 0.2369 - acc: 0.9552
# Epoch 26/50
#  - 0s - loss: 0.2244 - acc: 0.9615
# Epoch 27/50
#  - 0s - loss: 0.2126 - acc: 0.9594
# Epoch 28/50
#  - 0s - loss: 0.2018 - acc: 0.9625
# Epoch 29/50
#  - 0s - loss: 0.1923 - acc: 0.9625
# Epoch 30/50
#  - 0s - loss: 0.1831 - acc: 0.9615
# Epoch 31/50
#  - 0s - loss: 0.1744 - acc: 0.9615
# Epoch 32/50
#  - 0s - loss: 0.1669 - acc: 0.9688
# Epoch 33/50
#  - 0s - loss: 0.1607 - acc: 0.9635
# Epoch 34/50
#  - 0s - loss: 0.1531 - acc: 0.9688
# Epoch 35/50
#  - 0s - loss: 0.1465 - acc: 0.9719
# Epoch 36/50
#  - 0s - loss: 0.1403 - acc: 0.9719
# Epoch 37/50
#  - 0s - loss: 0.1348 - acc: 0.9729
# Epoch 38/50
#  - 0s - loss: 0.1315 - acc: 0.9708
# Epoch 39/50
#  - 0s - loss: 0.1247 - acc: 0.9729
# Epoch 40/50
#  - 0s - loss: 0.1198 - acc: 0.9740
# Epoch 41/50
#  - 0s - loss: 0.1155 - acc: 0.9750
# Epoch 42/50
#  - 0s - loss: 0.1110 - acc: 0.9771
# Epoch 43/50
#  - 0s - loss: 0.1076 - acc: 0.9781
# Epoch 44/50
#  - 0s - loss: 0.1041 - acc: 0.9823
# Epoch 45/50
#  - 0s - loss: 0.1001 - acc: 0.9823
# Epoch 46/50
#  - 0s - loss: 0.0971 - acc: 0.9802
# Epoch 47/50
#  - 0s - loss: 0.0940 - acc: 0.9792
# Epoch 48/50
#  - 0s - loss: 0.0905 - acc: 0.9823
# Epoch 49/50
#  - 0s - loss: 0.0877 - acc: 0.9802
# Epoch 50/50
#  - 0s - loss: 0.0848 - acc: 0.9865

# %%
model.metrics_names
# Out:
# ['loss', 'acc']

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
y_pred = model.predict_classes(X_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[170,  59],
#        [  0, 183]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#         0.0       1.00      0.74      0.85       229
#         1.0       0.76      1.00      0.86       183
#
# avg / total       0.89      0.86      0.86       412

# %%
model.save('DATA\SavedData\kerasBasics.h5')

# %%
from keras.models import load_model

# %%
savedModel = load_model('DATA\SavedData\kerasBasics.h5')

# %%
y_pred2 = savedModel.predict_classes(X_test)

# %%
confusion_matrix(y_test, y_pred2)
# Out:
# array([[170,  59],
#        [  0, 183]], dtype=int64)
